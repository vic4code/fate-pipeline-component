# %% [markdown]
# # Federated classic CTR model training on Criteo
#
# In this tutorial, we show you how to develop a horizontal federated recommendation model. We use the third-party library torch-rechub to call some classic recommendation models such as FM, DeepFM, etc., and use it to build a federated task in FATE. In terms of the dataset, we use the Criteo dataset which has been sampled and preprocessed, with a total of 50K data. For convenience, in this tutorial, all clients use the same dataset.

# %% [markdown]
# ## Install Torch-rechub
#
# We will use torch-rechub from:https://github.com/datawhalechina/torch-rechub.
# To run this tutorial, you need to install the latest-version:
#
# - git clone https://github.com/datawhalechina/torch-rechub.git
# - cd torch-rechub
# - python setup.py install

# %% [markdown]
# ## The Criteo
# The Criteo dataset is an online advertising dataset released by Criteo Labs. It contains millions of records of click feedback for displayed ads, which can be used as a benchmark for click-through rate (CTR) prediction. The dataset has 40 features, with the first column being the label, where a value of 1 indicates that the ad was clicked and a value of 0 indicates that the ad was not clicked. The other features include 13 dense features and 26 sparse features.
#
# - Dowload sampled data used in this tutorial here:
# -
#   https://webank-ai-1251170195.cos.ap-guangzhou.myqcloud.com/fate/examples/data/criteo.csv
#
#   And then put the csv under /examples/data.
#
# - The origin source of the criteo dataset is: https://ailab.criteo.com/ressources/

# %% [markdown]
# ### Construct dataset class
#
# Here we will construct a Criteo dataset that read the csv. At the same time, it will process the dataset and return
# information about dense&sparse features.

# %%
pwd
# Out:
# '/data/projects/fate/doc/tutorial/pipeline/nn_tutorial'

# %%
import sys
sys.path.append('/data/projects/fate/persistence/torch-rechub')

# %%
from pipeline.component.nn import save_to_fate

# %%
# %%save_to_fate dataset criteo_dataset.py
# from sklearn.preprocessing import MinMaxScaler, LabelEncoder
# from tqdm import tqdm
# import pandas as pd
# import numpy as np
# from federatedml.nn.dataset.base import Dataset
# from torch_rechub.basic.features import DenseFeature, SparseFeature
#
# class CriteoDataset(Dataset):
#
#     def __init__(self):
#         # super().__init__()
#         super(CriteoDataset, self).__init__()
#         self.x = None
#         self.y = None
#         self.sample_ids= None
#
#     # load dataset and process
#     def load(self, data_path):
#
#         # convert numeric features
#         def convert_numeric_feature(val):
#             v = int(val)
#             if v > 2:
#                 return int(np.log(v)**2)
#             else:
#                 return v - 2
#         # load data
#         if data_path.endswith(".gz"):  #if the raw_data is gz file:
#             data = pd.read_csv(data_path, compression="gzip")
#         else:
#             data = pd.read_csv(data_path)
#         print("data load finished")
#         # print(data.info())
#         if 'sid' in data.columns:
#             self.sample_ids = list(data.sid)
#
#         # feature_process
#         dense_features = [f for f in data.columns.tolist() if f[0] == "I"]
#         sparse_features = [f for f in data.columns.tolist() if f[0] == "C"]
#
#         data[sparse_features] = data[sparse_features].fillna('0')
#         data[dense_features] = data[dense_features].fillna(0)
#
#         for feat in tqdm(dense_features):  #discretize dense feature and as new sparse feature
#             sparse_features.append(feat + "_cat")
#             data[feat + "_cat"] = data[feat].apply(lambda x: convert_numeric_feature(x))
#
#         sca = MinMaxScaler()  #scaler dense feature
#         data[dense_features] = sca.fit_transform(data[dense_features])
#
#         for feat in tqdm(sparse_features):  #encode sparse feature
#             lbe = LabelEncoder()
#             data[feat] = lbe.fit_transform(data[feat])
#
#         def get_dense_feat(name):
#             return DenseFeature(name), {'name': name}
#         dense_feas = []
#         dense_feas_dict = []
#         for feature_name in dense_features:
#             a,b = get_dense_feat(feature_name)
#             dense_feas.append(a)
#             dense_feas_dict.append(b)
#
#         def get_sparse_feat(name, vocab_size,embed_dim):
#             return SparseFeature(name, vocab_size,embed_dim), {'name': name, 'vocab_size': vocab_size,'embed_dim':embed_dim}
#
#         sparse_feas=[]
#         sparse_feas_dict=[]
#         for feature_name in sparse_features:
#             a,b = get_sparse_feat(name=feature_name, vocab_size=data[feature_name].nunique(), embed_dim=16)
#             sparse_feas.append(a)
#             sparse_feas_dict.append(b)
#
#         ffm_linear_feas = []
#         ffm_linear_feas_dict = []
#         def get_ffm_linear_feat(name, vocab_size,embed_dim):
#             return SparseFeature(name, vocab_size,embed_dim), {'name': name, 'vocab_size': vocab_size,'embed_dim':embed_dim}
#         for feature in sparse_feas:
#             a,b = get_ffm_linear_feat(name = feature.name, vocab_size=feature.vocab_size, embed_dim=1)
#             ffm_linear_feas.append(a)
#             ffm_linear_feas_dict.append(b)
#
#         ffm_cross_feas = []
#         ffm_cross_feas_dict = []
#         def get_ffm_cross_feat(name, vocab_size,embed_dim):
#             return SparseFeature(name, vocab_size,embed_dim), {'name': name, 'vocab_size': vocab_size,'embed_dim':embed_dim}
#         for feature in sparse_feas:
#             a,b = get_ffm_cross_feat(name = feature.name, vocab_size=feature.vocab_size*len(sparse_feas), embed_dim=10)
#             ffm_cross_feas.append(a)
#             ffm_cross_feas_dict.append(b)
#
#         y = data["label"]
#         del data["label"]
#         x = data
#
#         # ncq:
#         self.x = x
#         self.y = y
#
#         return dense_feas, dense_feas_dict,sparse_feas,sparse_feas_dict, ffm_linear_feas,ffm_linear_feas_dict, ffm_cross_feas, ffm_cross_feas_dict
#
#     def __getitem__(self, index):
#         return {k: v[index] for k, v in self.x.items()}, self.y[index].astype(np.float32)
#
#     def __len__(self):
#         return len(self.y)
#
#     def get_sample_ids(self,):
#         return self.sample_ids

# %% [markdown]
# ### CTR Models
# Here based on Torch-rechub, we develop four kinds of CTR models: FM, FFM, DeepFM and DeepFFM

# %%
# %%save_to_fate model fm_model.py
# import torch
# from torch_rechub.basic.layers import FM,LR,EmbeddingLayer
# from torch_rechub.basic.features import DenseFeature, SparseFeature
# class FMModel(torch.nn.Module):
#   '''
#   A standard FM models
#   '''
#   def __init__(self, dense_feas_dict, sparse_feas_dict):
#       super(FMModel, self).__init__()
#       dense_features = []
#       def recover_dense_feat(dict_):
#         return DenseFeature(name=dict_['name'])
#
#       for i in dense_feas_dict:
#         dense_features.append(recover_dense_feat(i))
#       self.dense_features = dense_features
#
#       sparse_features = []
#       def recover_sparse_feat(dict_):
#           return SparseFeature(dict_['name'], dict_['vocab_size'],dict_['embed_dim'])
#
#       for i in sparse_feas_dict:
#         sparse_features.append(recover_sparse_feat(i))
#       self.sparse_features = sparse_features
#
#       self.fm_features = self.sparse_features
#       self.fm_dims = sum([fea.embed_dim for fea in self.fm_features])
#       self.linear = LR(self.fm_dims)  # 1-odrder interaction
#       self.fm = FM(reduce_sum=True)  # 2-odrder interaction
#       self.embedding = EmbeddingLayer(self.fm_features)
#
#   def forward(self, x):
#       input_fm = self.embedding(x, self.fm_features, squeeze_dim=False)  #[batch_size, num_fields, embed_dim]input_fm: torch.Size([100, 39, 16])
#       # print('input_fm:',input_fm.shape) # input_fm: torch.Size([100, 39, 16]) (batch_size, num_features, embed_dim)
#       y_linear = self.linear(input_fm.flatten(start_dim=1))
#       y_fm = self.fm(input_fm)
#       # print('y_fm.shape:',y_fm.shape) # y_fm.shape: torch.Size([100, 1])
#
#       y = y_linear + y_fm
#       return torch.sigmoid(y.squeeze(1))

# %%
# %%save_to_fate model deepfm_model.py
# import torch
# from torch_rechub.basic.layers import FM,LR,EmbeddingLayer,MLP
# from torch_rechub.basic.features import DenseFeature, SparseFeature
#
# class DeepFMModel(torch.nn.Module):
#     """Deep Factorization Machine Model
#     Args:
#         deep_features (list): the list of `Feature Class`, training by the deep part module.
#         fm_features (list): the list of `Feature Class`, training by the fm part module.
#         mlp_params (dict): the params of the last MLP module, keys include:`{"dims":list, "activation":str, "dropout":float, "output_layer":bool`}
#     """
#
#     def __init__(self, dense_feas_dict, sparse_feas_dict, mlp_params):
#         super(DeepFMModel, self).__init__()
#         dense_features = []
#         def recover_dense_feat(dict_):
#             return DenseFeature(name=dict_['name'])
#
#         for i in dense_feas_dict:
#             dense_features.append(recover_dense_feat(i))
#         self.dense_features = dense_features
#
#         sparse_features = []
#         def recover_sparse_feat(dict_):
#             return SparseFeature(dict_['name'], dict_['vocab_size'],dict_['embed_dim'])
#
#         for i in sparse_feas_dict:
#             sparse_features.append(recover_sparse_feat(i))
#         self.deep_features = dense_features
#         self.fm_features = sparse_features
#
#         self.deep_dims = sum([fea.embed_dim for fea in dense_features])
#         self.fm_dims = sum([fea.embed_dim for fea in sparse_features])
#         self.linear = LR(self.fm_dims)  # 1-odrder interaction
#         self.fm = FM(reduce_sum=True)  # 2-odrder interaction
#         self.embedding = EmbeddingLayer(dense_features + sparse_features)
#         self.mlp = MLP(self.deep_dims, **mlp_params)
#
#     def forward(self, x):
#         input_deep = self.embedding(x, self.deep_features, squeeze_dim=True)  #[batch_size, deep_dims]
#         input_fm = self.embedding(x, self.fm_features, squeeze_dim=False)  #[batch_size, num_fields, embed_dim]
#
#         y_linear = self.linear(input_fm.flatten(start_dim=1))
#         y_fm = self.fm(input_fm)
#         y_deep = self.mlp(input_deep)  #[batch_size, 1]
#         y = y_linear + y_fm + y_deep
#         return torch.sigmoid(y.squeeze(1))

# %%
# %%save_to_fate model ffm_model.py
# import torch
# from torch_rechub.basic.layers import LR,EmbeddingLayer,FFM,FM
# import torch
# from torch_rechub.basic.features import DenseFeature, SparseFeature
#
# class FFMModel(torch.nn.Module):
#
#     def __init__(self, liner_feas_dict, cross_feas_dict):
#         super(FFMModel, self).__init__()
#         linear_features = []
#         def recover_ffm_linear_feat(dict_):
#             return SparseFeature(dict_['name'], dict_['vocab_size'],dict_['embed_dim'])
#
#         for i in liner_feas_dict:
#             linear_features.append(recover_ffm_linear_feat(i))
#
#         cross_features = []
#         def recover_ffm_cross_feat(dict_):
#             return SparseFeature(dict_['name'], dict_['vocab_size'],dict_['embed_dim'])
#
#         for i in cross_feas_dict:
#             cross_features.append(recover_ffm_cross_feat(i))
#         self.linear_features = linear_features
#         self.cross_features = cross_features
#         self.num_fields = len(cross_features)
#         self.num_field_cross = self.num_fields * (self.num_fields - 1) // 2
#         # print('num_fields:',self.num_fields) #39
#         self.ffm = FFM(num_fields=self.num_fields, reduce_sum=False)
#         self.linear_embedding = EmbeddingLayer(linear_features)
#         self.ffm_embedding = EmbeddingLayer(cross_features)
#         self.b =torch.nn.Parameter(torch.zeros(1))
#         fields_offset = torch.arange(0, self.num_fields, dtype=torch.long)
#         self.register_buffer('fields_offset', fields_offset)
#         self.fm = FM(reduce_sum=True)
#
#     def forward(self, x):
#         y_linear = self.linear_embedding(x, self.linear_features, squeeze_dim=True).sum(1, keepdim=True) #[batch_size, 1]
#         # output shape [batch_size, num_field, num_field, emb_dim]
#         x_ffm = {fea.name: x[fea.name].unsqueeze(1) * self.num_fields  + self.fields_offset for fea in self.cross_features}
#         input_ffm = self.ffm_embedding(x_ffm, self.cross_features, squeeze_dim=False)
#         # print('input_ffm.shape:',input_ffm.shape) # torch.Size([100, 39, 39, 10])
#         em = self.ffm(input_ffm)
#         # print('output_ffm.shape:',em.shape)
#         # torch.Size([100, 741, 10])(batch_size, num_fields*(num_fields-1)/2,embed_dim)
#         y_ffm = self.fm(em)
#         # compute scores from the ffm part of the model, output shape [batch_size, 1]
#         # print('y_linear.shape:',y_linear.shape)  # torch.Size([100,1])
#         y = y_linear + y_ffm
#         return torch.sigmoid(y.squeeze(1)+ self.b)

# %%
# %%save_to_fate model deepffm_model.py
# import torch
# from torch import nn
# from torch_rechub.basic.features import SparseFeature
# from torch_rechub.models.ranking import DeepFFM
#
# class DeepFFMModel(nn.Module):
#     def __init__(self,ffm_linear_feas_dict, ffm_cross_feas_dict):
#         super().__init__()
#         linear_features = []
#         cross_features = []
#
#         def recover_sparse_feat(dict_):
#             return SparseFeature(dict_['name'], dict_['vocab_size'],dict_['embed_dim'])
#
#         for i in ffm_linear_feas_dict:
#             linear_features.append(recover_sparse_feat(i))
#         for i in ffm_cross_feas_dict:
#             cross_features.append(recover_sparse_feat(i))
#         self.model = DeepFFM(linear_features=linear_features, cross_features=cross_features, embed_dim=10, mlp_params={"dims": [1600, 1600], "dropout": 0.5, "activation": "relu"})
#
#     def forward(self, x):
#         return self.model(x)

# %% [markdown]
# ## Local Testing
# Test this set (dataset + model) locally to see if it can run, and omit the federated aggregation part during local validation.

# %%
import torch
from federatedml.nn.homo.trainer.fedavg_trainer import FedAVGTrainer

ds = CriteoDataset()
path = '../../../../examples/data/criteo.csv'

dense_feas, dense_feas_dict, sparse_feas, sparse_feas_dict, ffm_linear_feas, \
        ffm_linear_feas_dict, ffm_cross_feas, ffm_cross_feas_dict = ds.load(path)

fm_model = FMModel(dense_feas_dict=dense_feas_dict,sparse_feas_dict=sparse_feas_dict)

ffm_model = FFMModel(liner_feas_dict=ffm_linear_feas_dict, cross_feas_dict=ffm_cross_feas_dict)

dfm_model = DeepFMModel(dense_feas_dict=dense_feas_dict,sparse_feas_dict=sparse_feas_dict, mlp_params={"dims": [256, 128], "dropout": 0.2, "activation": "relu"})

dffm_model = DeepFFMModel(ffm_linear_feas_dict=ffm_linear_feas_dict,ffm_cross_feas_dict=ffm_cross_feas_dict)

model = fm_model
# Out:
# data load finished
# 100%|██████████| 26/26 [00:06<00:00,  4.17it/s]
# 100%|██████████| 52/52 [00:01<00:00, 43.03it/s]

# %%
# here we test one model: the FM Model
trainer = FedAVGTrainer(epochs=1, batch_size=256)
trainer.local_mode()
trainer.set_model(model)
trainer.train(ds, None, optimizer=torch.optim.Adam(model.parameters(), lr=0.01), loss=torch.nn.BCELoss())
# Out:
# epoch is 0
# 100%|██████████| 1954/1954 [03:28<00:00,  9.36it/s]
# epoch loss is 1.340322400100708

# %% [markdown]
# ## Submit a Pipeline to run a federation task

# %% [markdown]
# ## [Warn] HDFS uploading is not supported in this stage

# %%
# !pipeline --help
# Out:
# Usage: pipeline [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   config  pipeline config tool
#  - DESCRIPTION: Pipeline Config Command.

# %%
# !pipeline init --ip 127.0.0.1 --port 9380
# Out:
# Pipeline configuration succeeded.

# %%
# !pipeline init --ip 127.0.0.1 --port 9380

# import pandas as pd
# df = pd.read_csv("/data/projects/fate/examples/data/criteo.csv")
# df["id"] = range(500000)
# df = pd.concat([df.loc[:,["id",'label']], df.iloc[:, :51]],axis=1)
# df.columns = [c.lower() for c in df.columns]
# df.iloc[:250000,:].to_csv("/data/projects/fate/examples/data/criteo_homo_guest.csv",index=False)
# df.iloc[250000:,:].to_csv("/data/projects/fate/examples/data/criteo_homo_host.csv",index=False)

# from pipeline.backend.pipeline import PipeLine
# pipeline_upload = PipeLine().set_initiator(role='guest', party_id=9999).set_roles(host=9999)
# partition = 4
# dense_data_guest = {"name": "criteo_homo_guest", "namespace": f"experiment"}
# dense_data_host = {"name": "criteo_homo_host", "namespace": f"experiment"}

# %%
pipeline_upload.upload(drop=1)
# Out:
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-06-13 10:37:10.423 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202306131036564117730
#
# 2023-06-13 10:37:10.431 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-06-13 10:37:11.440 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-06-13 10:37:12.456 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-06-13 10:37:12.457 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-06-13 10:37:13.472 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-06-13 10:37:14.487 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-06-13 10:37:15.502 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-06-13 10:37:16.517 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-06-13 10:37:17.532 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-06-13 10:37:18.547 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:08
# 2023-06-13 10:37:19.563 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:09
# 2023-06-13 10:37:20.579 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:10
# 2023-06-13 10:37:21.594 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:11
# 2023-06-13 10:37:22.610 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:12
# 2023-06-13 10:37:23.626 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:13
# 2023-06-13 10:37:24.641 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:14
# 2023-06-13 10:37:25.657 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:15
# 2023-06-13 10:37:26.667 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202306131036564117730
# 2023-06-13 10:37:26.668 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:16
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-06-13 10:37:40.429 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202306131037266726960
#
# 2023-06-13 10:37:40.437 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-06-13 10:37:41.455 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-06-13 10:37:41.457 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:01
# 2023-06-13 10:37:42.471 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-06-13 10:37:43.497 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-06-13 10:37:44.513 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-06-13 10:37:45.528 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-06-13 10:37:46.543 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-06-13 10:37:47.558 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-06-13 10:37:48.574 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:08
# 2023-06-13 10:37:49.589 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:09
# 2023-06-13 10:37:50.604 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:10
# 2023-06-13 10:37:51.620 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:11
# 2023-06-13 10:37:52.635 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:12
# 2023-06-13 10:37:53.651 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:13
# 2023-06-13 10:37:54.665 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:14
# 2023-06-13 10:37:55.680 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:15
# 2023-06-13 10:37:56.694 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:16
# 2023-06-13 10:37:57.708 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:17
# 2023-06-13 10:37:58.722 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:18
# 2023-06-13 10:37:59.738 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:19
# 2023-06-13 10:38:00.747 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202306131037266726960
# 2023-06-13 10:38:00.748 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:20
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-06-13 10:38:14.585 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202306131038007524490
#
# 2023-06-13 10:38:14.593 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-06-13 10:38:15.602 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# 2023-06-13 10:38:16.613 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:02
# m2023-06-13 10:38:17.628 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-06-13 10:38:17.630 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-06-13 10:38:18.644 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-06-13 10:38:19.659 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-06-13 10:38:20.674 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-06-13 10:38:21.689 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-06-13 10:38:22.704 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:08
# 2023-06-13 10:38:23.719 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:09
# 2023-06-13 10:38:24.734 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:10
# 2023-06-13 10:38:25.749 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:11
# 2023-06-13 10:38:26.763 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:12
# 2023-06-13 10:38:27.778 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:13
# 2023-06-13 10:38:28.794 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:14
# 2023-06-13 10:38:29.808 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:15
# 2023-06-13 10:38:30.821 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:16
# 2023-06-13 10:38:31.836 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:17
# 2023-06-13 10:38:32.851 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:18
# 2023-06-13 10:38:33.865 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:19
# 2023-06-13 10:38:35.938 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202306131038007524490
# 2023-06-13 10:38:35.939 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:21

# %%
from federatedml.nn.dataset.criteo_dataset import CriteoDataset
import numpy as np
import pandas as pd
from pipeline.interface import Data, Model
from pipeline.component import Reader, Evaluation, DataTransform
from pipeline.backend.pipeline import PipeLine
from pipeline.component import HomoNN
from pipeline import fate_torch_hook
from torch import nn
import torch as t
import os
from pipeline.component.homo_nn import DatasetParam, TrainerParam 

fate_torch_hook(t)

fate_project_path = os.path.abspath('../../../../')
data_path = 'examples/data/criteo.csv'
host = 10000
guest = 9999
arbiter = 10000
pipeline = PipeLine().set_initiator(role='guest', party_id=guest).set_roles(guest=guest, host=host, arbiter=arbiter)

data = {"name": "criteo", "namespace": "experiment"}
pipeline.bind_table(name=data['name'],
                    namespace=data['namespace'], path=fate_project_path + '/' + data_path)

# reader
reader_0 = Reader(name="reader_0")
reader_0.get_party_instance(
    role='guest', party_id=guest).component_param(table=data)
reader_0.get_party_instance(
    role='host', party_id=host).component_param(table=data)

# reader_0 = Reader(name="reader_0")
# reader_0.get_party_instance(
#     role='guest', party_id=guest).component_param(table={"name": "criteo_homo_guest", "namespace": "experiment"})
# reader_0.get_party_instance(
#     role='host', party_id=host).component_param(table={"name": "criteo_homo_host", "namespace": "experiment"})


# data_transform_0 = DataTransform(name='data_transform_0')
# data_transform_0.get_party_instance(
#     role='guest', party_id=guest).component_param(
#     with_label=True, label_name='label', output_format="dense")
# data_transform_0.get_party_instance(
#     role='host', party_id=host).component_param(
#     with_label=True, label_name='label', output_format="dense")

# compute model parameter for our CTR models
ds = CriteoDataset()
dense_feas, dense_feas_dict, sparse_feas, sparse_feas_dict, ffm_linear_feas, ffm_linear_feas_dict, \
        ffm_cross_feas, ffm_cross_feas_dict = ds.load(fate_project_path + '/' + data_path)

model = t.nn.Sequential(
    t.nn.CustModel(module_name='fm_model', class_name='FMModel', dense_feas_dict=dense_feas_dict, sparse_feas_dict=sparse_feas_dict)
)

nn_component = HomoNN(name='nn_0',
                      model=model, 
                      loss=t.nn.BCELoss(),
                      optimizer=t.optim.Adam(
                          model.parameters(), lr=0.001, weight_decay=0.001),
                      dataset=DatasetParam(dataset_name='criteo_dataset'),
                      trainer=TrainerParam(trainer_name='fedavg_trainer', epochs=1, batch_size=256, validation_freqs=1,
                                           data_loader_worker=6, shuffle=True),
                      torch_seed=100 
                      )

pipeline.add_component(reader_0)
# pipeline.add_component(data_transform_0, data=Data(data=reader_0.output.data))
# pipeline.add_component(nn_component, data=Data(train_data=data_transform_0.output.data))
pipeline.add_component(nn_component, data=Data(train_data=reader_0.output.data))
pipeline.add_component(Evaluation(name='eval_0', eval_type='binary'), data=Data(data=nn_component.output.data))
pipeline.compile()
pipeline.fit()
# Out:
# data load finished
# 100%|██████████| 26/26 [00:06<00:00,  4.19it/s]
# 100%|██████████| 52/52 [00:01<00:00, 43.61it/s]
# 2023-06-13 12:35:10.908 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202306131235104264300
#
# 2023-06-13 12:35:10.916 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-06-13 12:35:11.926 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-06-13 12:35:12.943 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-06-13 12:35:12.945 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-06-13 12:35:13.960 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-06-13 12:35:14.975 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-06-13 12:35:15.990 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2023-06-13 12:35:17.022 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2023-06-13 12:35:18.038 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:07
# 2023-06-13 12:35:19.053 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:08
# 2023-06-13 12:35:20.069 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:09
# 2023-06-13 12:35:21.088 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:10
# 2023-06-13 12:35:22.110 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:11
# 2023-06-13 12:35:23.129 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:12
# 2023-06-13 12:35:24.147 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:13
# 2023-06-13 12:35:25.189 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:14
# 2023-06-13 12:35:26.207 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:15
# 2023-06-13 12:35:27.224 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:16
# 2023-06-13 12:35:28.244 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:17
# 2023-06-13 12:35:29.288 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:18
# 2023-06-13 12:35:30.310 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:19
# m2023-06-13 12:35:32.349 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-06-13 12:35:32.350 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:21
# 2023-06-13 12:35:33.366 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:22
# 2023-06-13 12:35:34.438 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:23
# 2023-06-13 12:35:35.454 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:24
# 2023-06-13 12:35:36.471 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:25
# 2023-06-13 12:35:37.486 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:26
# 2023-06-13 12:35:38.507 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:27
# 2023-06-13 12:35:39.536 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:28
# 2023-06-13 12:35:40.556 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:29
# 2023-06-13 12:35:41.574 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:30
# 2023-06-13 12:35:42.592 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:31
# 2023-06-13 12:35:43.611 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:32
# 2023-06-13 12:35:44.628 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:33
# 2023-06-13 12:35:45.644 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:34
# 2023-06-13 12:35:46.662 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:35
# 2023-06-13 12:35:47.679 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:36
# 2023-06-13 12:35:48.696 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:37
# 2023-06-13 12:35:49.715 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:38
# 2023-06-13 12:35:50.735 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:39
# 2023-06-13 12:35:51.756 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:40
# 2023-06-13 12:35:52.776 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:41
# 2023-06-13 12:35:53.794 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:42
# 2023-06-13 12:35:54.810 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:43
# 2023-06-13 12:35:55.827 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:44
# 2023-06-13 12:35:56.842 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:45
# 2023-06-13 12:35:57.859 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:46
# 2023-06-13 12:35:58.876 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:47
# 2023-06-13 12:35:59.892 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:48
# 2023-06-13 12:36:00.908 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:50
# 2023-06-13 12:36:01.924 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:51
# 2023-06-13 12:36:02.941 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:52
# 2023-06-13 12:36:03.958 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:53
# 2023-06-13 12:36:04.976 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:54
# 2023-06-13 12:36:05.993 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:55
# 2023-06-13 12:36:07.010 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:56
# 2023-06-13 12:36:08.028 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:57
# 2023-06-13 12:36:09.044 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:58
# 2023-06-13 12:36:10.059 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:59
# 2023-06-13 12:36:11.075 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:00
# 2023-06-13 12:36:12.089 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:01
# 2023-06-13 12:36:13.105 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:02
# 2023-06-13 12:36:14.121 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:03
# 2023-06-13 12:36:15.137 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:04
# 2023-06-13 12:36:16.152 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:05
# 2023-06-13 12:36:17.168 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:06
# 2023-06-13 12:36:18.183 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:07
# 2023-06-13 12:36:19.200 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:08
# 2023-06-13 12:36:20.216 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:09
# 2023-06-13 12:36:21.231 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:10
# 2023-06-13 12:36:22.247 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:11
# 2023-06-13 12:36:23.262 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:12
# 2023-06-13 12:36:24.279 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:13
# 2023-06-13 12:36:25.295 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:14
# 2023-06-13 12:36:26.310 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:15
# 2023-06-13 12:36:27.325 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:16
# 2023-06-13 12:36:28.342 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:17
# 2023-06-13 12:36:29.358 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:18
# 2023-06-13 12:36:30.374 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:19
# 2023-06-13 12:36:31.390 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:20
# 2023-06-13 12:36:32.405 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:21
# 2023-06-13 12:36:33.421 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:22
# 2023-06-13 12:36:34.436 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:23
# 2023-06-13 12:36:35.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:24
# 2023-06-13 12:36:36.466 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:25
# 2023-06-13 12:36:37.485 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:26
# 2023-06-13 12:36:38.499 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:27
# 2023-06-13 12:36:39.515 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:28
# 2023-06-13 12:36:40.534 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:29
# 2023-06-13 12:36:41.550 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:30
# 2023-06-13 12:36:42.571 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:31
# 2023-06-13 12:36:43.587 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:32
# 2023-06-13 12:36:44.609 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:33
# 2023-06-13 12:36:45.624 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:34
# 2023-06-13 12:36:46.645 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:35
# 2023-06-13 12:36:47.661 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:36
# 2023-06-13 12:36:48.677 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:37
# 2023-06-13 12:36:49.693 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:38
# 2023-06-13 12:36:50.708 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:39
# 2023-06-13 12:36:51.724 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:40
# 2023-06-13 12:36:52.740 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:41
# 2023-06-13 12:36:53.756 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:42
# 2023-06-13 12:36:54.771 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:43
# 2023-06-13 12:36:55.788 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:44
# 2023-06-13 12:36:56.803 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:45
# 2023-06-13 12:36:57.819 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:46
# 2023-06-13 12:36:58.835 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:47
# 2023-06-13 12:36:59.850 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:48
# 2023-06-13 12:37:00.865 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:49
# 2023-06-13 12:37:01.882 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:50
# 2023-06-13 12:37:02.897 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:51
# 2023-06-13 12:37:03.912 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:53
# 2023-06-13 12:37:04.929 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:54
# 2023-06-13 12:37:05.945 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:55
# 2023-06-13 12:37:06.960 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:56
# 2023-06-13 12:37:07.976 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:57
# 2023-06-13 12:37:08.991 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:58
# 2023-06-13 12:37:10.007 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:01:59
# 2023-06-13 12:37:11.024 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:00
# 2023-06-13 12:37:12.038 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:01
# 2023-06-13 12:37:13.054 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:02
# 2023-06-13 12:37:14.071 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:03
# 2023-06-13 12:37:15.087 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:04
# 2023-06-13 12:37:16.104 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:05
# 2023-06-13 12:37:17.119 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:06
# 2023-06-13 12:37:18.135 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:07
# 2023-06-13 12:37:19.152 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:08
# 2023-06-13 12:37:20.168 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:09
# 2023-06-13 12:37:21.188 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:10
# 2023-06-13 12:37:22.203 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:11
# 2023-06-13 12:37:23.219 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:12
# 2023-06-13 12:37:24.235 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:13
# 2023-06-13 12:37:25.251 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:14
# 2023-06-13 12:37:26.276 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:15
# 2023-06-13 12:37:27.291 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:16
# 2023-06-13 12:37:28.307 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:17
# 2023-06-13 12:37:29.322 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:18
# 2023-06-13 12:37:30.336 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:19
# 2023-06-13 12:37:31.366 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:20
# 2023-06-13 12:37:32.381 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:21
# 2023-06-13 12:37:33.397 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:22
# 2023-06-13 12:37:34.413 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:23
# 2023-06-13 12:37:35.428 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:24
# 2023-06-13 12:37:36.448 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:25
# 2023-06-13 12:37:37.463 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:26
# 2023-06-13 12:37:38.478 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:27
# 2023-06-13 12:37:39.494 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:28
# 2023-06-13 12:37:40.509 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:29
# 2023-06-13 12:37:41.525 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:30
# 2023-06-13 12:37:42.543 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:31
# 2023-06-13 12:37:43.560 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:32
# 2023-06-13 12:37:44.577 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:33
# 2023-06-13 12:37:45.592 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:34
# 2023-06-13 12:37:46.608 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:35
# 2023-06-13 12:37:47.623 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:36
# 2023-06-13 12:37:48.639 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:37
# 2023-06-13 12:37:49.655 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:38
# 2023-06-13 12:37:50.670 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:39
# 2023-06-13 12:37:51.687 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:40
# 2023-06-13 12:37:52.708 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:41
# 2023-06-13 12:37:53.723 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:42
# 2023-06-13 12:37:54.738 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:43
# 2023-06-13 12:37:55.753 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:44
# 2023-06-13 12:37:56.769 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:45
# 2023-06-13 12:37:57.789 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:46
# 2023-06-13 12:37:58.804 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:47
# 2023-06-13 12:37:59.819 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:48
# 2023-06-13 12:38:00.835 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:49
# 2023-06-13 12:38:01.850 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:50
# 2023-06-13 12:38:02.866 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:51
# 2023-06-13 12:38:03.881 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:52
# 2023-06-13 12:38:04.897 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:53
# 2023-06-13 12:38:05.913 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:55
# 2023-06-13 12:38:06.929 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:56
# 2023-06-13 12:38:07.945 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:57
# 2023-06-13 12:38:08.961 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:58
# 2023-06-13 12:38:09.980 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:02:59
# 2023-06-13 12:38:10.995 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:00
# 2023-06-13 12:38:12.012 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:01
# 2023-06-13 12:38:13.027 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:02
# 2023-06-13 12:38:14.042 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:03
# 2023-06-13 12:38:15.063 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:04
# 2023-06-13 12:38:16.079 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:05
# 2023-06-13 12:38:17.095 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:06
# 2023-06-13 12:38:18.111 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:07
# 2023-06-13 12:38:19.129 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:08
# 2023-06-13 12:38:20.143 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:09
# 2023-06-13 12:38:21.158 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:10
# 2023-06-13 12:38:22.173 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:11
# 2023-06-13 12:38:23.189 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:12
# 2023-06-13 12:38:24.205 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:13
# 2023-06-13 12:38:25.219 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:14
# 2023-06-13 12:38:26.242 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:15
# 2023-06-13 12:38:27.258 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:16
# 2023-06-13 12:38:28.273 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:17
# 2023-06-13 12:38:29.288 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:18
# 2023-06-13 12:38:30.303 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:19
# 2023-06-13 12:38:31.318 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:20
# 2023-06-13 12:38:32.333 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:21
# 2023-06-13 12:38:33.349 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:22
# 2023-06-13 12:38:34.365 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:23
# 2023-06-13 12:38:35.380 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:24
# 2023-06-13 12:38:36.396 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:25
# 2023-06-13 12:38:37.420 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:26
# 2023-06-13 12:38:38.435 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:27
# 2023-06-13 12:38:39.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:28
# 2023-06-13 12:38:40.466 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:29
# 2023-06-13 12:38:41.482 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:30
# 2023-06-13 12:38:42.501 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:31
# 2023-06-13 12:38:43.518 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:32
# 2023-06-13 12:38:44.537 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:33
# 2023-06-13 12:38:45.552 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:34
# 2023-06-13 12:38:46.567 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:35
# 2023-06-13 12:38:47.598 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:36
# 2023-06-13 12:38:48.613 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:37
# 2023-06-13 12:38:49.635 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:38
# 2023-06-13 12:38:50.650 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:39
# 2023-06-13 12:38:51.673 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:40
# 2023-06-13 12:38:52.689 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:41
# 2023-06-13 12:38:53.705 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:42
# 2023-06-13 12:38:54.720 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:43
# 2023-06-13 12:38:55.736 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:44
# 2023-06-13 12:38:56.751 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:45
# 2023-06-13 12:38:57.767 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:46
# 2023-06-13 12:38:58.791 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:47
# 2023-06-13 12:38:59.807 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:48
# 2023-06-13 12:39:00.823 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:49
# 2023-06-13 12:39:01.838 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:50
# 2023-06-13 12:39:02.854 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:51
# 2023-06-13 12:39:03.874 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:52
# 2023-06-13 12:39:04.891 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:53
# 2023-06-13 12:39:05.908 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:55
# 2023-06-13 12:39:06.924 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:56
# 2023-06-13 12:39:07.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:57
# 2023-06-13 12:39:08.955 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:58
# 2023-06-13 12:39:09.971 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:03:59
# 2023-06-13 12:39:10.987 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:00
# 2023-06-13 12:39:12.003 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:01
# 2023-06-13 12:39:13.018 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:02
# 2023-06-13 12:39:14.035 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:03
# 2023-06-13 12:39:15.056 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:04
# 2023-06-13 12:39:16.072 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:05
# 2023-06-13 12:39:17.089 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:06
# 2023-06-13 12:39:18.106 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:07
# 2023-06-13 12:39:19.122 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:08
# 2023-06-13 12:39:20.138 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:09
# 2023-06-13 12:39:21.154 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:10
# 2023-06-13 12:39:22.169 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:11
# 2023-06-13 12:39:23.184 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:12
# 2023-06-13 12:39:24.200 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:13
# 2023-06-13 12:39:25.217 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:14
# 2023-06-13 12:39:26.234 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:15
# 2023-06-13 12:39:27.249 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:16
# 2023-06-13 12:39:28.265 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:17
# 2023-06-13 12:39:29.281 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:18
# 2023-06-13 12:39:30.297 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:19
# 2023-06-13 12:39:31.313 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:20
# 2023-06-13 12:39:32.328 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:21
# 2023-06-13 12:39:33.343 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:22
# 2023-06-13 12:39:34.359 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:23
# 2023-06-13 12:39:35.375 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:24
# 2023-06-13 12:39:36.392 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:25
# 2023-06-13 12:39:37.407 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:26
# 2023-06-13 12:39:38.423 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:27
# 2023-06-13 12:39:39.438 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:28
# 2023-06-13 12:39:40.454 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:29
# 2023-06-13 12:39:41.476 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:30
# 2023-06-13 12:39:42.492 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:31
# 2023-06-13 12:39:43.511 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:32
# 2023-06-13 12:39:44.527 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:33
# 2023-06-13 12:39:45.543 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:34
# 2023-06-13 12:39:46.563 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:35
# 2023-06-13 12:39:47.579 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:36
# 2023-06-13 12:39:48.594 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:37
# 2023-06-13 12:39:49.609 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:38
# 2023-06-13 12:39:50.625 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:39
# 2023-06-13 12:39:51.640 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:40
# 2023-06-13 12:39:52.656 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:41
# 2023-06-13 12:39:53.671 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:42
# 2023-06-13 12:39:54.687 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:43
# 2023-06-13 12:39:55.702 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:44
# 2023-06-13 12:39:56.716 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:45
# 2023-06-13 12:39:57.740 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:46
# 2023-06-13 12:39:58.755 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:47
# 2023-06-13 12:39:59.770 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:48
# 2023-06-13 12:40:00.786 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:49
# 2023-06-13 12:40:01.801 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:50
# 2023-06-13 12:40:02.817 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:51
# 2023-06-13 12:40:03.834 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:52
# 2023-06-13 12:40:04.850 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:53
# 2023-06-13 12:40:05.866 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:54
# 2023-06-13 12:40:06.882 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:55
# 2023-06-13 12:40:07.897 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:56
# 2023-06-13 12:40:08.912 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:58
# 2023-06-13 12:40:09.927 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:04:59
# 2023-06-13 12:40:10.943 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:00
# 2023-06-13 12:40:11.959 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:01
# 2023-06-13 12:40:12.974 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:02
# 2023-06-13 12:40:13.989 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:03
# 2023-06-13 12:40:15.004 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:04
# 2023-06-13 12:40:16.020 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:05
# 2023-06-13 12:40:17.037 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:06
# 2023-06-13 12:40:18.052 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:07
# 2023-06-13 12:40:19.074 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:08
# 2023-06-13 12:40:20.090 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:09
# 2023-06-13 12:40:21.106 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:05:10
# ...
# 2023-06-13 13:29:18.809 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:07
# 2023-06-13 13:29:19.825 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:08
# 2023-06-13 13:29:20.844 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:09
# 2023-06-13 13:29:21.859 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:10
# 2023-06-13 13:29:22.875 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:11
# 2023-06-13 13:29:23.890 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:12
# 2023-06-13 13:29:24.905 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:13
# 2023-06-13 13:29:25.920 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:15
# 2023-06-13 13:29:26.936 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:16
# 2023-06-13 13:29:27.952 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:17
# 2023-06-13 13:29:28.966 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:18
# 2023-06-13 13:29:29.982 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:19
# 2023-06-13 13:29:30.998 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:20
# 2023-06-13 13:29:32.019 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:21
# 2023-06-13 13:29:33.034 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:22
# 2023-06-13 13:29:34.049 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:23
# 2023-06-13 13:29:35.064 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:24
# 2023-06-13 13:29:36.079 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:25
# 2023-06-13 13:29:37.094 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:26
# 2023-06-13 13:29:38.115 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:27
# 2023-06-13 13:29:39.131 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:28
# 2023-06-13 13:29:40.148 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:29
# 2023-06-13 13:29:41.164 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:30
# 2023-06-13 13:29:42.179 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:31
# 2023-06-13 13:29:43.193 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:32
# 2023-06-13 13:29:44.209 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:33
# 2023-06-13 13:29:45.224 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:34
# 2023-06-13 13:29:46.240 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:35
# 2023-06-13 13:29:47.255 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:36
# 2023-06-13 13:29:48.271 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:37
# 2023-06-13 13:29:49.290 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:38
# 2023-06-13 13:29:50.304 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:39
# 2023-06-13 13:29:51.320 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:40
# 2023-06-13 13:29:52.335 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:41
# 2023-06-13 13:29:53.351 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:42
# 2023-06-13 13:29:54.367 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:43
# 2023-06-13 13:29:55.393 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:44
# 2023-06-13 13:29:56.409 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:45
# 2023-06-13 13:29:57.424 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:46
# 2023-06-13 13:29:58.439 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:47
# 2023-06-13 13:29:59.455 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:48
# 2023-06-13 13:30:00.470 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:49
# 2023-06-13 13:30:01.486 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:50
# 2023-06-13 13:30:02.502 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:51
# 2023-06-13 13:30:03.519 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:52
# 2023-06-13 13:30:04.535 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:53
# 2023-06-13 13:30:05.550 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:54
# 2023-06-13 13:30:06.570 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:55
# 2023-06-13 13:30:07.585 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:56
# 2023-06-13 13:30:08.600 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:57
# 2023-06-13 13:30:09.616 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:58
# 2023-06-13 13:30:10.631 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:54:59
# 2023-06-13 13:30:11.646 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:00
# 2023-06-13 13:30:12.669 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:01
# 2023-06-13 13:30:13.685 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:02
# 2023-06-13 13:30:14.700 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:03
# 2023-06-13 13:30:15.716 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:04
# 2023-06-13 13:30:16.731 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:05
# 2023-06-13 13:30:17.745 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:06
# 2023-06-13 13:30:18.760 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:07
# 2023-06-13 13:30:19.776 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:08
# 2023-06-13 13:30:20.791 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:09
# 2023-06-13 13:30:21.807 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:10
# 2023-06-13 13:30:22.822 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:11
# 2023-06-13 13:30:23.841 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:12
# 2023-06-13 13:30:24.857 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:13
# 2023-06-13 13:30:25.873 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:14
# 2023-06-13 13:30:26.888 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:15
# 2023-06-13 13:30:27.903 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:16
# 2023-06-13 13:30:28.918 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:18
# 2023-06-13 13:30:29.939 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:19
# 2023-06-13 13:30:30.955 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:20
# 2023-06-13 13:30:31.970 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:21
# 2023-06-13 13:30:32.985 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:22
# 2023-06-13 13:30:34.000 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:23
# 2023-06-13 13:30:35.015 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:24
# 2023-06-13 13:30:36.030 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:25
# 2023-06-13 13:30:37.045 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:26
# 2023-06-13 13:30:38.061 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:27
# 2023-06-13 13:30:39.076 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:28
# 2023-06-13 13:30:40.091 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:29
# 2023-06-13 13:30:41.117 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:30
# 2023-06-13 13:30:42.133 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:31
# 2023-06-13 13:30:43.147 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:32
# 2023-06-13 13:30:44.163 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:33
# 2023-06-13 13:30:45.180 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:34
# 2023-06-13 13:30:46.196 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:35
# 2023-06-13 13:30:47.211 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:36
# 2023-06-13 13:30:48.227 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:37
# 2023-06-13 13:30:49.242 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:38
# 2023-06-13 13:30:50.257 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:39
# 2023-06-13 13:30:51.272 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:40
# 2023-06-13 13:30:52.287 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:41
# 2023-06-13 13:30:53.302 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:42
# 2023-06-13 13:30:54.318 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:43
# 2023-06-13 13:30:55.331 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:44
# 2023-06-13 13:30:56.346 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:45
# 2023-06-13 13:30:57.378 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:46
# 2023-06-13 13:30:58.393 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:47
# 2023-06-13 13:30:59.414 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:48
# 2023-06-13 13:31:00.431 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:49
# 2023-06-13 13:31:01.446 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:55:50
